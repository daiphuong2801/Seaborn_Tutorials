# %% [markdown]
# # 1. Khai báo thư viện

# %%
# Cú pháp: import (tên thư viện) as (viết tắt tên thư viện)

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Vẽ các đồ thị bên trong cell
# %matplotlib inline

# %% [markdown]
# # 2. Lấy dữ liệu

# %% [markdown]
# ## 2.1. Dữ liệu không có sẵn trong Seaborn

# %%
#Cú pháp:

#Đặt tên + Tải dữ liệu: Tên cần đặt = pd.read_csv('./Địa chỉ file.csv')
#Xuất dữ liệu: Tên cần đặt (Cách 1)

# %%
#cereal_df = pd.read_csv('./data/cereal.csv')
cereal_df = pd.read_csv('./cereal.csv')
cereal_df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
#Cú pháp:

#Đặt tên + Tải dữ liệu: Tên cần đặt = pd.read_csv('./Địa chỉ file.csv')
#Xuất dữ liệu: Tên cần đặt.head() (Cách 2)

# %%
cereal_df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
#Cú pháp:

#Đặt tên + Tải dữ liệu: Tên cần đặt = pd.read_csv('./Địa chỉ file.csv')
#Xuất dữ liệu: Tên cần đặt.tail() (Cách 3)

# %%
cereal_df.tail()
# Out:
#                    name mfr type  calories  protein  fat  sodium  fiber  \
# 72              Triples   G    C       110        2    1     250    0.0
# 73                 Trix   G    C       110        1    1     140    0.0
# 74           Wheat Chex   R    C       100        3    1     230    3.0
# 75             Wheaties   G    C       100        3    1     200    3.0
# 76  Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 72   21.0       3      60        25      3     1.0  0.75  39.106174
# 73   13.0      12      25        25      2     1.0  1.00  27.753301
# 74   17.0       3     115        25      1     1.0  0.67  49.787445
# 75   17.0       3     110        25      1     1.0  1.00  51.592193
# 76   16.0       8      60        25      1     1.0  0.75  36.187559

# %% [markdown]
# ## 2.2. Dữ liệu có sẵn trong Seaborn

# %%
#Xuất tên datasets có sẵn trong Seaborn
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'taxis', 'tips', 'titanic']

# %%
#Cú pháp:

#Đặt tên: Tên cần đặt = sns.load_dataset('tên dataset')
#Xuất dữ liệu: Tên cần đặt

# %%
tips_df = sns.load_dataset('tips')
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # 3. Trực quan hóa dữ liệu với Seaborn

# %% [markdown]
# ## 3.1. Các biểu đồ phổ biến

# %% [markdown]
# Distribution: Histogram, KDE (Kernel Density Estimate), Displot
#
# Bar Plot
#
# Count Plot
#
# Box Plot: Phương pháp để mô tả bằng đồ thị các nhóm dữ liệu số thông qua các phần tư của chúng
#
# Facet Plot: Tạo ra một lưới 2d gồm các bảng được xác định bởi các biến tạo thành các hàng và cột.
#
# Join Plot
#
# Pair Plot
#
# Heat Map: một kỹ thuật trực quan hóa dữ liệu cho thấy cường độ của một hiện tượng là màu sắc ở hai chiều

# %% [markdown]
# ## 3.2. Trực quan hóa dữ liệu

# %%
sns.set_style('dark')

# %% [markdown]
# ### 3.2.1. Distribution Plot

# %% [markdown]
# ### a. Histogram Plot

# %%
#Cú pháp: sns.hisplot(data = Tên cần đặt, x = 'Chỉ tiêu').set(title = 'TÊN BIỂU ĐỒ')

#Các parameter bổ sung:
#     hue: phân biệt chỉ tiêu bất kỳ theo màu
#     hue_order: hoán đổi thứ tự của hue
#     multiple (layer, dodge, stack, fill): kiểu hiển thị của hue
#     stat (count, frequency, probability/proportion, percent, density): kiểu hiển thị giá trị ở trục tung (stat = 'count' => mặc định)
#     element (bars, step, poly): kiểu hiển thị của chỉ tiêu ở trục hoành 
#     kde = True/False: hiển thị/không hiển thị KDE Plot

# %%
sns.histplot(data = tips_df, x = "total_bill", multiple = "stack",
             kde = False, element = 'bars', hue ='sex').set(title = 'TOTAL BILL COVERED BY GENDER')
# Out:
# [Text(0.5, 1.0, 'TOTAL BILL COVERED BY GENDER')]

# %% [markdown]
# ### b. KDE (Kernel Density Estimate) Plot

# %%
#Cú pháp: sns.kdeplot(data = Tên cần đặt, x = 'Chỉ tiêu').set(title = 'TÊN BIỂU ĐỒ')

#Các parameter bổ sung:
#     hue: phân biệt chỉ tiêu bất kỳ theo màu
#     hue_order: hoán đổi thứ tự của hue
#     multiple (layer, stack, fill): kiểu hiển thị của hue (multiple = 'layer' => mặc định)

# %%
sns.kdeplot(data=tips_df, x ='total_bill', hue = 'sex', multiple = 'layer').set(title = 'TOTAL BILL COVERED BY GENDER')
# Out:
# [Text(0.5, 1.0, 'TOTAL BILL COVERED BY GENDER')]

# %% [markdown]
# ### c. Displot

# %%
#Cú pháp:
# 1 plot: 
#   sns.displot(data = Tên cần đặt, x = 'Chỉ tiêu').set(title = 'TÊN BIỂU ĐỒ')

# >= 2 plots (dùng col):
#   Tên tạm = sns.displot(data = Tên cần đặt, x = 'Chỉ tiêu')
#   Tên tạm.fig.suptitle('TÊN BIỂU ĐỒ') => Đặt tên biểu đồ
#   Tên tạm.fig.subplots_adjust(top/bottom = Kích thước) => Điều chỉnh kích thước tên biểu đồ

#Các parameter bổ sung:
#   col: phân biệt chỉ tiêu bất kỳ theo biểu đồ 
#   hue: phân biệt chỉ tiêu bất kỳ theo màu
#   hue_order: hoán đổi thứ tự của hue
#   multiple (layer, dodge, stack, fill): kiểu hiển thị giá trị ở trục tung 
#   kde = True/False: hiển thị/không hiển thị KDE Plot
#   kind (hist, kde, ecdf): kiểu biểu đồ muốn hiển thị (kind = 'hist' => mặc định)
#   stat (count, frequency, probability/proportion, percent, density): kiểu hiển thị giá trị ở trục tung (stat = 'count' => mặc định)

# %%
tbill = sns.displot(data = tips_df, x = 'total_bill', col = 'time', 
                    hue = 'sex', multiple='stack', kde = True, kind = 'hist')

tbill.fig.suptitle('TOTAL BILL COVERED BY GENDER')
tbill.fig.subplots_adjust(top = .9)

# %% [markdown]
# ### 3.2.2. Bar Plot

# %%
#Cú pháp:
#  sns.barplot(data = Tên cần đặt, x = 'Chỉ tiêu 1', y = 'Chỉ tiêu 2').set(title = 'TÊN BIỂU ĐỒ')

#Các parameter bổ sung:
#  hue: phân biệt chỉ tiêu bất kỳ theo màu
#  hue_order: hoán đổi thứ tự của hue

# %%
sns.barplot(data = tips_df, x = 'day', y = 'total_bill',
            hue = 'smoker', hue_order = ['No','Yes']).set(title = 'TOTAL BILL COVERED BY SMOKER ON WEEKDAYS')
# Out:
# [Text(0.5, 1.0, 'TOTAL BILL COVERED BY SMOKER ON WEEKDAYS')]

# %% [markdown]
# ### 3.2.3. Count Plot

# %%
#Xuất dataset "titanic"
titan_df = sns.load_dataset("titanic")
titan_df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#Đếm 1 chỉ tiêu 

#Cú pháp: Tên cần đặt['Chỉ tiêu'].value_counts()

# %%
titan_df['alive'].value_counts()
# Out:
# no     549
# yes    342
# Name: alive, dtype: int64

# %%
#Cú pháp: sns.countplot(data = Tên cần đặt, x = 'Chỉ tiêu').set(title = 'TÊN BIỂU ĐỒ')

#Các parameter bổ sung:
#     hue: phân biệt chỉ tiêu bất kỳ theo màu
#     hue_order: hoán đổi thứ tự của hue

# %%
sns.countplot(data=titan_df, x = 'alive', hue_order = ['child', 'man', 'woman'],
              hue = 'who').set(title = 'PEOPLE WHO ARE ALIVE OR NOT FROM DIFFERENT AGES')
# Out:
# [Text(0.5, 1.0, 'PEOPLE WHO ARE ALIVE OR NOT FROM DIFFERENT AGES')]

# %% [markdown]
# ### 3.2.4. Box Plot

# %%
#Cú pháp: 
#sns.boxplot(data = Tên cần đặt, x = 'Chỉ tiêu 1', y = 'Chỉ tiêu 2').set(title = 'TÊN BIỂU ĐỒ')

#Các parameter bổ sung:
# hue: phân biệt chỉ tiêu bất kỳ theo màu
# hue_order: hoán đổi thứ tự của hue

# %%
sns.boxplot(data = tips_df, x = 'day', y = 'total_bill', hue = 'smoker').set(title = "TOTAL BILL COVERED BY SMOKER ON WEEKDAYS")
# Out:
# [Text(0.5, 1.0, 'TOTAL BILL COVERED BY SMOKER ON WEEKDAYS')]

# %% [markdown]
# ### 3.2.5. FacetGrid

# %%
#Cú pháp:
# 1 plot: 
#     Tên class = sns.FacetGrid(data = Tên cần đặt)
#     Tên class.map_dataframe(sns.histplot/scatterplot, x = 'Chỉ tiêu 1',
#                            y = 'Chỉ tiêu 2').set(title = 'TÊN BIỂU ĐỒ')

# >= 2 plots (dùng col):
#     Tên class = sns.FacetGrid(data = Tên cần đặt)
#     Tên class.map_dataframe(sns.histplot/scatterplot, x = 'Chỉ tiêu 1', y = 'Chỉ tiêu 2')
#     Tên class.fig.suptitle('TÊN BIỂU ĐỒ') => Đặt tên biểu đồ
#     Tên class.fig.subplots_adjust(top/bottom = Kích thước) => Điều chỉnh kích thước tên biểu đồ

#Các parameter bổ sung:
#     col: phân biệt chỉ tiêu bất kỳ theo cột
#     row: phân biệt chỉ tiêu bất kỳ theo dòng
#     hue: phân biệt chỉ tiêu bất kỳ theo màu
#     hue/row/col_order: hoán đổi thứ tự của hue/row/col

# %%
#Scatter Plot

fg = sns.FacetGrid(data=tips_df, hue = 'smoker')
fg.map_dataframe(sns.scatterplot, x = "total_bill", 
                 y = "tip").set(title = 'TIP AND TOTAL BILL COVERED BY SMOKER')
fg.add_legend() # hiển thị chú thích khi có hue

# %%
#Histogram Plot

fg = sns.FacetGrid(data = tips_df, col = "time",  row = "sex")
fg.map_dataframe(sns.histplot, x = "total_bill")
fg.fig.suptitle('TOTAL BILL COVERED BY GENDER AND TIME')
fg.fig.subplots_adjust(top = .9)

# %% [markdown]
# ### 3.2.6. LM Plot

# %%
#Cú pháp:

# 1 plot: 
#   sns.lmplot(data = Tên cần đặt, x = 'Chỉ tiêu', y = 'Chỉ tiêu 2').set(title = 'TÊN BIỂU ĐỒ')

# >= 2 plots (dùng col):
#   Tên tạm = sns.lmplot(data = Tên cần đặt, x = 'Chỉ tiêu')
#   Tên tạm.fig.suptitle('TÊN BIỂU ĐỒ') => Đặt tên biểu đồ
#   Tên tạm.fig.subplots_adjust(top/bottom = Kích thước) => Điều chỉnh kích thước tên biểu đồ

#Các parameter bổ sung:
# col: hiển thị từng giá trị vào biểu đồ
# hue: thay đổi kiểu hiển thị của giá trị (dùng khi có annot)
# markers (o, x, s, D, +): ký hiệu chú thích (khi dùng hue)

# %%
tb = sns.lmplot(data = tips_df, x = 'total_bill', y = 'tip', col = 'sex', hue = 'smoker', markers = ['+','o'])
tb.fig.suptitle('CORRELATION BETWEEN TOTAL BILL AND TIP BY GENDER AND SMOKER') 
tb.fig.subplots_adjust(top = .9)

# %% [markdown]
# ### 3.2.7. Joint Plot

# %%
tips_df = sns.load_dataset('tips')
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#Cú pháp: 
#     Tên tạm = sns.jointplot(data = Tên cần đặt, x = 'Chỉ tiêu 1', y = 'Chỉ tiêu 2')
#     Tên tạm.fig.suptitle('TÊN BIỂU ĐỒ')
#     Tên tạm.fig.subplots_adjust(top/bottom = kích thước)

#Các parameter bổ sung:
#     hue: phân biệt chỉ tiêu bất kỳ theo màu
#     hue_order: hoán đổi thứ tự của hue
#     kind (scatter, kde, hist, hex, reg, resid): kiểu biểu đồ muốn hiển thị
#                          (hue không đi kèm kind = 'hex', 'reg', 'resid')
#     xlim,ylim: khoảng giá trị được hiển thị trên trục x,y

# %%
tb = sns.jointplot(data = tips_df, x = 'tip', y = 'total_bill', hue = 'smoker', kind = 'scatter', ylim = [0,60])
tb.fig.suptitle('CORRELATION BETWEEN TOTAL BILL AND TIP BY SMOKER') 
tb.fig.subplots_adjust(top = .9)

# %% [markdown]
# ### 3.2.8. Pair Plot

# %%
pg_df = sns.load_dataset('penguins')
pg_df.tail()
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 339  Gentoo  Biscoe             NaN            NaN                NaN
# 340  Gentoo  Biscoe            46.8           14.3              215.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 342  Gentoo  Biscoe            45.2           14.8              212.0
# 343  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male

# %%
#Cú pháp:
#     Tên tạm = sns.pairplot(data = Tên cần đặt)
#     Tên tạm.fig.suptitle('TÊN BIỂU ĐỒ') => Đặt tên biểu đồ
#     Tên tạm.fig.subplots_adjust(top/bottom = kích thước) => Điều chỉnh kích thước tên biểu đồ

#Các parameter bổ sung:
#     hue: phân biệt chỉ tiêu bất kỳ theo màu
#     kind (scatter, kde, hist, reg): kiểu biểu đồ muốn hiển thị => mặc định: kind = 'scatter'
#     diag_kind (auto, hist, kde, None): kiểu biểu đồ muốn hiển thị đối với đường chéo chính
#     markers (o, x, s, D, +): ký hiệu chú thích (khi dùng hue)

# %%
pg = sns.pairplot(data = pg_df, hue = 'species', diag_kind = 'hist', markers = ['o','s','D'])
pg.fig.suptitle('CORRELATION BETWEEN BODY PARTS OF 3 PENGUINS') 
pg.fig.subplots_adjust(top = .9)

# %% [markdown]
# ### 3.2.9. Heat Map

# %%
fl_df = sns.load_dataset('flights')
fl_df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
#Sắp xếp dữ liệu 

#Cú pháp: Tên table = pd.pivot_table(data = Tên cần đặt, index = 'Chỉ tiêu theo hàng',
#                                    columns = 'Chỉ tiêu theo cột', values = 'Giá trị')

# %%
fls = pd.pivot_table(data = fl_df, index = 'month', columns = 'year', values = 'passengers')
fls.head()
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472

# %%
#Cú pháp: sns.heatmap(data = Tên cần đặt) .set(title = 'TÊN BIỂU ĐỒ')

#Các parameter bổ sung:
# annot: hiển thị từng giá trị vào biểu đồ
# fmt (d,f): thay đổi kiểu hiển thị của giá trị (dùng khi có annot)
# cbar = True/False: hiển thị/không hiển thị thanh màu sắc
# vmin,vmax: giá trị nhỏ nhất, lớn nhất của thanh màu sắc

# %%
sns.heatmap(data = fls, annot = True, fmt = 'd', cbar = True,
            vmin = 0, vmax = 700).set(title = 'PASSENGERS OF FLIGHTS FROM 1949 TO 1960')
# Out:
# [Text(0.5, 1.0, 'PASSENGERS OF FLIGHTS FROM 1949 TO 1960')]
